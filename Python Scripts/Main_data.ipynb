# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams['text.usetex'] = True
rcParams["font.family"] = "Times New Roman"

# %% [markdown]
# Plotting for r5 EOS

# %%
file_path_ADM_r5_11 = 'Grid2/Twin_r5_11/output-0000/data/ADMMass_VolumeMass[0]..asc'  
file_path_ADM_r5_12 = 'Grid2/Twin_r5_12/output-0000/data/ADMMass_VolumeMass[0]..asc'  
file_path_ADM_r5_13 = 'Grid2/Twin_r5_13/output-0000/data/ADMMass_VolumeMass[0]..asc'

file_path_rho_r5_11 = 'Grid2/Twin_r5_11/output-0000/data/rho.maximum.asc'  
file_path_rho_r5_12 = 'Grid2/Twin_r5_12/output-0000/data/rho.maximum.asc'  
file_path_rho_r5_13 = 'Grid2/Twin_r5_13/output-0000/data/rho.maximum.asc'
Rho_Data_11 = np.loadtxt(file_path_rho_r5_11, skiprows=6)
Rho_Data_12 = np.loadtxt(file_path_rho_r5_12, skiprows=6)
Rho_Data_13 = np.loadtxt(file_path_rho_r5_13, skiprows=6)

file_path_mp10_r5_11 = 'Grid2/Twin_r5_11/output-0000/data/mp_Psi4_l2_m2_r10.00.asc'  
file_path_mp10_r5_12 = 'Grid2/Twin_r5_12/output-0000/data/mp_Psi4_l2_m2_r10.00.asc'  
file_path_mp10_r5_13 = 'Grid2/Twin_r5_13/output-0000/data/mp_Psi4_l2_m2_r10.00.asc'
mp10Data_11 = np.loadtxt(file_path_mp10_r5_11, skiprows=0)
mp10Data_12 = np.loadtxt(file_path_mp10_r5_12, skiprows=0)
mp10Data_13 = np.loadtxt(file_path_mp10_r5_13, skiprows=0)

file_path_mp15_r5_11 = 'Grid2/Twin_r5_11/output-0000/data/mp_Psi4_l2_m2_r15.00.asc'  
file_path_mp15_r5_12 = 'Grid2/Twin_r5_12/output-0000/data/mp_Psi4_l2_m2_r15.00.asc'  
file_path_mp15_r5_13 = 'Grid2/Twin_r5_13/output-0000/data/mp_Psi4_l2_m2_r15.00.asc'
mp15Data_11 = np.loadtxt(file_path_mp15_r5_11, skiprows=0)
mp15Data_12 = np.loadtxt(file_path_mp15_r5_12, skiprows=0)
mp15Data_13 = np.loadtxt(file_path_mp15_r5_13, skiprows=0)

# %%
with open(file_path_ADM_r5_11, 'r') as file_ADM_r5_11:
    content_ADM_r5_11 = file_ADM_r5_11.readlines()
data_start_index_ADM_r5_11 = next(i for i, line in enumerate(content_ADM_r5_11) if not line.startswith('#'))
data_lines_ADM_r5_11 = content_ADM_r5_11[data_start_index_ADM_r5_11:]
data_ADM_r5_11 = np.loadtxt(data_lines_ADM_r5_11, usecols=(0, 8, 12))
iterations_ADM_r5_11 = data_ADM_r5_11[:, 0]
time_ADM_r5_11 = data_ADM_r5_11[:, 1] /203
mass_ADM_r5_11 = data_ADM_r5_11[:, 2] * 8

with open(file_path_ADM_r5_12, 'r') as file_ADM_r5_12:
    content_ADM_r5_12 = file_ADM_r5_12.readlines()
data_start_index_ADM_r5_12 = next(i for i, line in enumerate(content_ADM_r5_12) if not line.startswith('#'))
data_lines_ADM_r5_12 = content_ADM_r5_12[data_start_index_ADM_r5_12:]
data_ADM_r5_12 = np.loadtxt(data_lines_ADM_r5_12, usecols=(0, 8, 12))
iterations_ADM_r5_12 = data_ADM_r5_12[:, 0]
time_ADM_r5_12 = data_ADM_r5_12[:, 1] / 203
mass_ADM_r5_12 = data_ADM_r5_12[:, 2] * 8

with open(file_path_ADM_r5_13, 'r') as file_ADM_r5_13:
    content_ADM_r5_13 = file_ADM_r5_13.readlines()
data_start_index_ADM_r5_13 = next(i for i, line in enumerate(content_ADM_r5_13) if not line.startswith('#'))
data_lines_ADM_r5_13 = content_ADM_r5_13[data_start_index_ADM_r5_13:]
data_ADM_r5_13 = np.loadtxt(data_lines_ADM_r5_13, usecols=(0, 8, 12))
iterations_ADM_r5_13 = data_ADM_r5_13[:, 0]
time_ADM_r5_13 = data_ADM_r5_13[:, 1] / 203
mass_ADM_r5_13 = data_ADM_r5_13[:, 2] * 8

# %%
Rho_r5_11       = []
Iteration_r5_11 = []
Time_r5_11      = []

Rho_r5_12       = []
Iteration_r5_12 = []
Time_r5_12      = []

Rho_r5_13       = []
Iteration_r5_13 = []
Time_r5_13      = []


for i in range(len(Rho_Data_11)):
    Iteration_r5_11.append(Rho_Data_11[i][0])
    Time_r5_11.append(Rho_Data_11[i][1] / 203)  
    Rho_r5_11.append(Rho_Data_11[i][2]/ (7.4237 * (1e-22))) 

for i in range(len(Rho_Data_12)):
    Iteration_r5_12.append(Rho_Data_12[i][0])
    Time_r5_12.append(Rho_Data_12[i][1] / 203)  
    Rho_r5_12.append(Rho_Data_12[i][2]/ (7.4237 * (1e-22))) 

for i in range(len(Rho_Data_13)):
    Iteration_r5_13.append(Rho_Data_13[i][0])
    Time_r5_13.append(Rho_Data_13[i][1] / 203)  
    Rho_r5_13.append(Rho_Data_13[i][2] / (7.4237 * (1e-22)))

# %%
mp10y_r5_11         = []
mp10Time_r5_11      = []

mp10y_r5_12         = []
mp10Time_r5_12      = []

mp10y_r5_13         = []
mp10Time_r5_13      = []


for i in range(len(mp10Data_11)):
    mp10Time_r5_11.append(mp10Data_11[i][0] / 203)
    mp10y_r5_11.append(mp10Data_11[i][1]) 

for i in range(len(mp10Data_12)):
    mp10Time_r5_12.append(mp10Data_12[i][0] / 203)  
    mp10y_r5_12.append(mp10Data_12[i][1]) 

for i in range(len(mp10Data_13)):
    mp10Time_r5_13.append(mp10Data_13[i][0] / 203)  
    mp10y_r5_13.append(mp10Data_13[i][1])

# %%
mp15y_r5_11         = []
mp15Time_r5_11      = []

mp15y_r5_12         = []
mp15Time_r5_12      = []

mp15y_r5_13         = []
mp15Time_r5_13      = []


for i in range(len(mp15Data_11)):
    mp15Time_r5_11.append(mp15Data_11[i][0] / 203)
    mp15y_r5_11.append(mp15Data_11[i][1]) 

for i in range(len(mp10Data_12)):
    mp15Time_r5_12.append(mp15Data_12[i][0] / 203)  
    mp15y_r5_12.append(mp15Data_12[i][1]) 

for i in range(len(mp10Data_13)):
    mp15Time_r5_13.append(mp15Data_13[i][0] / 203)  
    mp15y_r5_13.append(mp15Data_13[i][1])

# %%
plt.figure(figsize=(10, 6))
plt.plot(time_ADM_r5_11, mass_ADM_r5_11, color='b',label='Twin Star A')
plt.plot(time_ADM_r5_12, mass_ADM_r5_12, color='r',label='Twin Star B' )
plt.plot(time_ADM_r5_13, mass_ADM_r5_13, color='g',label='Twin Star C')
#plt.title('Time Evolution of ADM Mass for r5 EOS')
plt.xlabel('Time [ms]')
plt.ylabel('ADM Mass $[M_{\odot}]$')
plt.legend(fontsize=15)
plt.xlim(0, 10) 
plt.ylim(1.1, 1.2) 
#plt.savefig('Twin_r5_ADMMass_time_evolution_data1.pdf', format='pdf',bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(time_ADM_r5_11, mass_ADM_r5_11, color='b',label='Twin Star A')
plt.plot(time_ADM_r5_12, mass_ADM_r5_12, color='r',label='Twin Star B' )
plt.plot(time_ADM_r5_13, mass_ADM_r5_13, color='g',label='Twin Star C')
#plt.title('Time Evolution of ADM Mass for r5 EOS')
plt.xlabel('Time [ms]', fontsize=15)
plt.ylabel('ADM Mass $[M_{\odot}]$', fontsize=15)
plt.legend(fontsize=15)
plt.xlim(0, 10) 
plt.ylim(1.1, 1.2) 
plt.savefig('Twin_r5_ADMMass_time_evolution_data.pdf', format='pdf',bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(Time_r5_11, Rho_r5_11, color='b', label='Twin Star A')
plt.plot(Time_r5_12, Rho_r5_12, color='r', label='Twin Star B')
plt.plot(Time_r5_13, Rho_r5_13, color='g', label='Twin Star C')
#plt.title('Time Evolution of Central Rest Mass Density for r5 EOS')
plt.xlabel('Time [ms]', fontsize=15)
plt.ylabel('Central Rest Mass Density [$kg~m^{-3}$]', fontsize=15)
plt.legend(fontsize=15)
plt.xlim(0, 10) 
# plt.ylim(0, 2.5) 
plt.savefig('Twin_r5_crmd_time_evolution_data.pdf', format='pdf',bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(mp10Time_r5_11, mp10y_r5_11, color='b', label='Twin Star A')
plt.plot(mp10Time_r5_12, mp10y_r5_12, color='r', label='Twin Star B')
plt.plot(mp10Time_r5_13, mp10y_r5_13, color='g', label='Twin Star C')
#plt.title('mp_Psi4_l2_m2_r10.00 Data for r5 EOS')
plt.xlabel('Time [ms]', fontsize=15)
#plt.ylabel('Central Rest Mass Density [$kg~m^{-3}$]', fontsize=15)
plt.legend(fontsize=15)
plt.xlim(0, 10) 
#plt.ylim(1.1, 1.2) 
plt.savefig('Twin_r5_mp_Psi4_l2_m2_r10.00_data.pdf', format='pdf',bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(mp15Time_r5_11, mp15y_r5_11, color='b', label='Twin Star A')
plt.plot(mp15Time_r5_12, mp15y_r5_12, color='r', label='Twin Star B')
plt.plot(mp15Time_r5_13, mp15y_r5_13, color='g', label='Twin Star C')
#plt.title('mp_Psi4_l2_m2_r15.00 Data for r5 EOS')
plt.xlabel('Time [ms]', fontsize=15)
#plt.ylabel('Central Rest Mass Density [$kg~m^{-3}$]', fontsize=15)
plt.legend(fontsize=15)
plt.xlim(0, 10) 
#plt.ylim(1.1, 1.2) 
plt.savefig('Twin_r5_mp_Psi4_l2_m2_r15.00_data.pdf', format='pdf',bbox_inches="tight")
plt.show()

# %% [markdown]
# Plotting for t2

# %%
#file_path_ADM_t2_13 = 'Grid2/Twin_t2_13/output-0000/data/ADMMass_VolumeMass[0]..asc'  
#file_path_ADM_t2_9 = 'Grid2/Twin_t2_9/output-0000/data/ADMMass_VolumeMass[0]..asc'  
#file_path_ADM_t2_8 = 'Grid2/Twin_t2_8/output-0000/data/ADMMass_VolumeMass[0]..asc'
file_path_ADM_t2_7 = 'Twin_t2_7/output-0000/data/ADMMass_VolumeMass[0]..asc'

#file_path_rho_t2_13 = 'Grid2/Twin_t2_13/output-0000/data/rho.maximum.asc'  
#file_path_rho_t2_9 = 'Grid2/Twin_t2_9/output-0000/data/rho.maximum.asc'  
#file_path_rho_t2_8 = 'Grid2/Twin_t2_8/output-0000/data/rho.maximum.asc'
file_path_rho_t2_7 = 'Twin_t2_7/output-0000/data/rho.maximum.asc'
#Rho_Data_t2_13 = np.loadtxt(file_path_rho_t2_13, skiprows=6)
#Rho_Data_t2_9 = np.loadtxt(file_path_rho_t2_9, skiprows=6)
#Rho_Data_t2_8 = np.loadtxt(file_path_rho_t2_8, skiprows=6)
Rho_Data_t2_7 = np.loadtxt(file_path_rho_t2_7, skiprows=6)

file_path_rho_t2_7g = 'Time Evolution/Grid1/Twin_t2_7/output-0000/data/rho.maximum.asc'
#Rho_Data_t2_13 = np.loadtxt(file_path_rho_t2_13, skiprows=6)
#Rho_Data_t2_9 = np.loadtxt(file_path_rho_t2_9, skiprows=6)
#Rho_Data_t2_8 = np.loadtxt(file_path_rho_t2_8, skiprows=6)
Rho_Data_t2_7g = np.loadtxt(file_path_rho_t2_7g, skiprows=6)


#file_path_mp10_t2_13 = 'Grid2/Twin_t2_13/output-0000/data/mp_Psi4_l2_m2_r10.00.asc'  
#file_path_mp10_t2_9 = 'Grid2/Twin_t2_9/output-0000/data/mp_Psi4_l2_m2_r10.00.asc'  
#file_path_mp10_t2_8 = 'Grid2/Twin_t2_8/output-0000/data/mp_Psi4_l2_m2_r10.00.asc'
file_path_mp10_t2_7 = 'Twin_t2_7/output-0000/data/mp_Psi4_l2_m2_r10.00.asc'
#mp10Data_t2_13 = np.loadtxt(file_path_mp10_t2_13, skiprows=0)
#mp10Data_t2_9 = np.loadtxt(file_path_mp10_t2_9, skiprows=0)
#mp10Data_t2_8 = np.loadtxt(file_path_mp10_t2_8, skiprows=0)
mp10Data_t2_7 = np.loadtxt(file_path_mp10_t2_7, skiprows=0)

#file_path_mp15_t2_13 = 'Grid2/Twin_t2_13/output-0000/data/mp_Psi4_l2_m2_r15.00.asc'  
#file_path_mp15_t2_9 = 'Grid2/Twin_t2_9/output-0000/data/mp_Psi4_l2_m2_r15.00.asc'  
#file_path_mp15_t2_8 = 'Grid2/Twin_t2_8/output-0000/data/mp_Psi4_l2_m2_r15.00.asc'
file_path_mp15_t2_7 = 'Twin_t2_7/output-0000/data/mp_Psi4_l2_m2_r15.00.asc'
#mp15Data_t2_13 = np.loadtxt(file_path_mp15_t2_13, skiprows=0)
#mp15Data_t2_9 = np.loadtxt(file_path_mp15_t2_9, skiprows=0)
#mp15Data_t2_8 = np.loadtxt(file_path_mp15_t2_8, skiprows=0)
mp15Data_t2_7 = np.loadtxt(file_path_mp15_t2_7, skiprows=0)

# %%
# with open(file_path_ADM_t2_13, 'r') as file_ADM_t2_13:
#     content_ADM_t2_13 = file_ADM_t2_13.readlines()
# data_start_index_ADM_t2_13 = next(i for i, line in enumerate(content_ADM_t2_13) if not line.startswith('#'))
# data_lines_ADM_t2_13 = content_ADM_t2_13[data_start_index_ADM_t2_13:]
# data_ADM_t2_13 = np.loadtxt(data_lines_ADM_t2_13, usecols=(0, 8, 12))
# iterations_ADM_t2_13 = data_ADM_t2_13[:, 0]
# time_ADM_t2_13 = data_ADM_t2_13[:, 1] /203
# mass_ADM_t2_13 = data_ADM_t2_13[:, 2] * 8

# with open(file_path_ADM_t2_9, 'r') as file_ADM_t2_9:
#     content_ADM_t2_9 = file_ADM_t2_9.readlines()
# data_start_index_ADM_t2_9 = next(i for i, line in enumerate(content_ADM_t2_9) if not line.startswith('#'))
# data_lines_ADM_t2_9 = content_ADM_t2_9[data_start_index_ADM_t2_9:]
# data_ADM_t2_9 = np.loadtxt(data_lines_ADM_t2_9, usecols=(0, 8, 12))
# iterations_ADM_t2_9 = data_ADM_t2_9[:, 0]
# time_ADM_t2_9 = data_ADM_t2_9[:, 1] / 203
# mass_ADM_t2_9 = data_ADM_t2_9[:, 2] * 8

# with open(file_path_ADM_t2_8, 'r') as file_ADM_t2_8:
#     content_ADM_t2_8 = file_ADM_t2_8.readlines()
# data_start_index_ADM_t2_8 = next(i for i, line in enumerate(content_ADM_t2_8) if not line.startswith('#'))
# data_lines_ADM_t2_8 = content_ADM_t2_8[data_start_index_ADM_t2_8:]
# data_ADM_t2_8 = np.loadtxt(data_lines_ADM_t2_8, usecols=(0, 8, 12))
# iterations_ADM_t2_8 = data_ADM_t2_8[:, 0]
# time_ADM_t2_8 = data_ADM_t2_8[:, 1] / 203
# mass_ADM_t2_8 = data_ADM_t2_8[:, 2] * 8

# with open(file_path_ADM_t2_7, 'r') as file_ADM_t2_7:
#     content_ADM_t2_7 = file_ADM_t2_7.readlines()
# data_start_index_ADM_t2_7 = next(i for i, line in enumerate(content_ADM_t2_7) if not line.startswith('#'))
# data_lines_ADM_t2_7 = content_ADM_t2_7[data_start_index_ADM_t2_7:]
# data_ADM_t2_7 = np.loadtxt(data_lines_ADM_t2_7, usecols=(0, 8, 12))
# iterations_ADM_t2_7 = data_ADM_t2_7[:, 0]
# time_ADM_t2_7 = data_ADM_t2_7[:, 1] / 203
# mass_ADM_t2_7 = data_ADM_t2_7[:, 2] * 8

# %%
# Rho_t2_13       = []
# Iteration_t2_13 = []
# Time_t2_13      = []

# Rho_t2_9       = []
# Iteration_t2_9 = []
# Time_t2_9      = []

# Rho_t2_8       = []
# Iteration_t2_8 = []
# Time_t2_8      = []

Rho_t2_7       = []
Iteration_t2_7 = []
Time_t2_7      = []

Rho_t2_7g       = []
Iteration_t2_7g = []
Time_t2_7g      = []

# for i in range(len(Rho_Data_t2_13)):
#     Iteration_t2_13.append(Rho_Data_t2_13[i][0])
#     Time_t2_13.append(Rho_Data_t2_13[i][1] / 203)  
#     Rho_t2_13.append(Rho_Data_t2_13[i][2]/ (7.4237 * (1e-22))) 

# for i in range(len(Rho_Data_t2_9)):
#     Iteration_t2_9.append(Rho_Data_t2_9[i][0])
#     Time_t2_9.append(Rho_Data_t2_9[i][1] / 203) 
#     Rho_t2_9.append(Rho_Data_t2_9[i][2]/ (7.4237 * (1e-22))) 

# for i in range(len(Rho_Data_t2_8)):
#     Iteration_t2_8.append(Rho_Data_t2_8[i][0])
#     Time_t2_8.append(Rho_Data_t2_8[i][1] / 203)  
#     Rho_t2_8.append(Rho_Data_t2_8[i][2] / (7.4237 * (1e-22))) 

for i in range(len(Rho_Data_t2_7)):
    Iteration_t2_7.append(Rho_Data_t2_7[i][0])
    Time_t2_7.append(Rho_Data_t2_7[i][1] / 203)  
    Rho_t2_7.append(Rho_Data_t2_7[i][2] / (7.4237 * (1e-22))) 

for i in range(len(Rho_Data_t2_7g)):
    Iteration_t2_7g.append(Rho_Data_t2_7g[i][0])
    Time_t2_7g.append(Rho_Data_t2_7g[i][1] / 203)  
    Rho_t2_7g.append(Rho_Data_t2_7g[i][2] / (7.4237 * (1e-22)))

# %%
mp10y_t2_13         = []
mp10Time_t2_13      = []

mp10y_t2_9         = []
mp10Time_t2_9      = []

mp10y_t2_8         = []
mp10Time_t2_8      = []

mp10y_t2_7         = []
mp10Time_t2_7      = []


for i in range(len(mp10Data_t2_13)):
    mp10Time_t2_13.append(mp10Data_t2_13[i][0] / 203)
    mp10y_t2_13.append(mp10Data_t2_13[i][1]) 

for i in range(len(mp10Data_t2_9)):
    mp10Time_t2_9.append(mp10Data_t2_9[i][0] / 203)  
    mp10y_t2_9.append(mp10Data_t2_9[i][1]) 

for i in range(len(mp10Data_t2_8)):
    mp10Time_t2_8.append(mp10Data_t2_8[i][0] / 203)  
    mp10y_t2_8.append(mp10Data_t2_8[i][1]) 

for i in range(len(mp10Data_t2_7)):
    mp10Time_t2_7.append(mp10Data_t2_7[i][0] / 203)  
    mp10y_t2_7.append(mp10Data_t2_7[i][1])

# %%
mp15y_t2_13         = []
mp15Time_t2_13      = []

mp15y_t2_9         = []
mp15Time_t2_9      = []

mp15y_t2_8         = []
mp15Time_t2_8      = []

mp15y_t2_7         = []
mp15Time_t2_7      = []


for i in range(len(mp15Data_t2_13)):
    mp15Time_t2_13.append(mp15Data_t2_13[i][0] / 203)
    mp15y_t2_13.append(mp15Data_t2_13[i][1]) 

for i in range(len(mp10Data_t2_9)):
    mp15Time_t2_9.append(mp15Data_t2_9[i][0] / 203)  
    mp15y_t2_9.append(mp15Data_t2_9[i][1]) 

for i in range(len(mp10Data_t2_8)):
    mp15Time_t2_8.append(mp15Data_t2_8[i][0] / 203)  
    mp15y_t2_8.append(mp15Data_t2_8[i][1]) 

for i in range(len(mp10Data_t2_7)):
    mp15Time_t2_7.append(mp15Data_t2_7[i][0] / 203)  
    mp15y_t2_7.append(mp15Data_t2_7[i][1])

# %%
plt.figure(figsize=(10, 6))
plt.plot(time_ADM_t2_7, mass_ADM_t2_7, color='k',label='Twin Star A')
plt.plot(time_ADM_t2_8, mass_ADM_t2_8, color='g',label='Twin Star B')
plt.plot(time_ADM_t2_9, mass_ADM_t2_9, color='r',label='Twin Star C')
plt.plot(time_ADM_t2_13, mass_ADM_t2_13, color='b',label='Twin Star D')

#plt.title('Time Evolution of ADM Mass for t2 EOS')
plt.xlabel('Time [ms]', fontsize=15)
plt.ylabel('ADM Mass $[M_{\odot}]$', fontsize=15)
plt.legend(fontsize=15)
plt.xlim(0, 10) 
plt.ylim(1, 1.8) 
plt.savefig('Twin_t2_ADMMass_time_evolution_data.pdf', format='pdf',bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(Time_t2_7, Rho_t2_7, color='r', label='Twin Star A Gridsize = 0.5')
plt.plot(Time_t2_7g, Rho_t2_7g, color='g', label='Twin Star A Gridsize = 0.25')
#plt.plot(Time_t2_9, Rho_t2_9, color='r', label='Twin Star C')
#plt.plot(Time_t2_13, Rho_t2_13, color='b', label='Twin Star D')

#plt.title('Time Evolution of Central Rest Mass Density for t2 EOS')
plt.xlabel('Time [ms]', fontsize=15)
plt.ylabel('Central Rest Mass Density [$kg~m^{-3}$]', fontsize=15)
plt.legend(fontsize=15)
plt.xlim(0, 5) 
#plt.ylim(1, 2) 
plt.savefig('Twin_t2_7_gridvary.pdf', format='pdf',bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(mp10Time_t2_7, mp10y_t2_7, color='k', label='Twin Star A')
plt.plot(mp10Time_t2_8, mp10y_t2_8, color='g', label='Twin Star B')
plt.plot(mp10Time_t2_9, mp10y_t2_9, color='r', label='Twin Star C')
plt.plot(mp10Time_t2_13, mp10y_t2_13, color='b', label='Twin Star D')

#plt.title('mp_Psi4_l2_m2_r10.00 Data for t2 EOS')
plt.xlabel('Time [ms]', fontsize=15)
#plt.ylabel('Central Rest Mass Density [$kg~m^{-3}$]', fontsize=15)
plt.legend(fontsize=15)
plt.xlim(0, 10) 
#plt.ylim(1.1, 1.2) 
plt.savefig('Twin_t2_mp_Psi4_l2_m2_r10.00_data.pdf', format='pdf',bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(8, 6))

plt.plot(mp15Time_t2_7, mp15y_t2_7, color='k', label='Twin Star A')
plt.plot(mp15Time_t2_8, mp15y_t2_8, color='g', label='Twin Star B')
plt.plot(mp15Time_t2_9, mp15y_t2_9, color='r', label='Twin Star C')
plt.plot(mp15Time_t2_13, mp15y_t2_13, color='b', label='Twin Star D')
#plt.title('mp_Psi4_l2_m2_r15.00 Data for t2 EOS')
plt.xlabel('Time [ms]', fontsize=15)
#plt.ylabel('Central Rest Mass Density [$kg~m^{-3}$]', fontsize=15)
plt.legend(fontsize=15)
plt.xlim(0, 10) 
#plt.ylim(1.1, 1.2) 

plt.savefig('Twin_t2_mp_Psi4_l2_m2_r15.00_data.pdf', format='pdf',bbox_inches="tight")
plt.show()
