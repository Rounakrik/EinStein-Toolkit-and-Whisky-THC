# %%
import numpy as np
import matplotlib as plt
import matplotlib.pyplot as plt
from kuibit.simdir import SimDir
from kuibit.grid_data import UniformGrid

# %%
# # Load simulation data
# gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Twin/Twin_Finder_r5/Twin_State/Twin_r5_radius133").gf
# rb_had = gf_had.xy.fields.rho

# # Define a smaller grid for the data
# small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[10, 10])
# rho_had = rb_had[0].to_UniformGridData_from_grid(small_grid)
# r_had = rho_had.data_xyz

# # Plotting
# plt.figure(figsize=(10, 10))
# plt.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')
# plt.colorbar(label='Log Density')
# plt.xlabel('X', fontsize=20)
# plt.ylabel('Y', fontsize=20)

# x_ticks = np.arange(0, 10.1, 0.1)
# plt.xticks(x_ticks, rotation=90)


# # Save and show the plot
# plt.savefig("log_crmd_5.7000817898485325e17_r5.pdf", format='pdf')
# plt.show()

# %%
# # Load simulation data
# gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Twin/Twin_Finder_r5/Twin_State/Twin_r5_radius133").gf
# rb_had = gf_had.xy.fields.rho

# # Define a smaller grid for the data
# small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[10, 10])
# rho_had = rb_had[0].to_UniformGridData_from_grid(small_grid)
# r_had = rho_had.data_xyz

# # Plotting
# plt.figure(figsize=(30, 15))
# plt.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')
# plt.colorbar(label='Density')
# plt.xlabel('X', fontsize=20)
# plt.ylabel('Y', fontsize=20)

# x_ticks = np.arange(0, 10.1, 0.1)
# plt.xticks(x_ticks, rotation=90)


# # Save and show the plot
# #plt.savefig("crmd_5.7000817898485325e17_r5.pdf", format='pdf')
# plt.show()

# %%
# gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Twin/Twin_Finder_r5/Twin_State/Twin_r5_radius1103").gf
# rb_had = gf_had.xy.fields.rho
# small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[10,10])
# rho_had =rb_had[0].to_UniformGridData_from_grid(small_grid)
# r_had=(rho_had.data_xyz)
# plt.figure(figsize=(30, 15))
# plt.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')
# plt.colorbar(label='Log Density')
# plt.xlabel('X', fontsize=20)
# plt.ylabel('Y', fontsize=20)

# x_ticks = np.arange(0, 10.1, 0.1)
# plt.xticks(x_ticks, rotation=90)
# plt.savefig("log_crmd_1.0764679483448372e18_r5.pdf", format='pdf')
# plt.show()

# %%
# gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Twin/Twin_Finder_r5/Twin_State/Twin_r5_radius1210").gf
# rb_had = gf_had.xy.fields.rho
# small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[10,10])
# rho_had =rb_had[0].to_UniformGridData_from_grid(small_grid)
# r_had=(rho_had.data_xyz)
# plt.figure(figsize=(30, 15))
# plt.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')
# plt.colorbar(label='Log Density')
# plt.xlabel('X', fontsize=20)
# plt.ylabel('Y', fontsize=20)

# x_ticks = np.arange(0, 10.1, 0.1)
# plt.xticks(x_ticks, rotation=90)
# plt.savefig("log_crmd_1.0392777109978394e18_r5.pdf", format='pdf')
# plt.show()

# %%
# gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Twin/Twin_Finder_t2/Twin_State/Twin_t2_radius8").gf
# rb_had = gf_had.xy.fields.rho
# small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[10,10])
# rho_had =rb_had[0].to_UniformGridData_from_grid(small_grid)
# r_had=(rho_had.data_xyz)
# plt.figure(figsize=(30, 15))
# plt.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')
# plt.colorbar(label='Log Density')
# plt.xlabel('X', fontsize=20)
# plt.ylabel('Y', fontsize=20)

# x_ticks = np.arange(0, 10.1, 0.1)
# plt.xticks(x_ticks, rotation=90)
# plt.savefig("log_crmd_3.5126769207020667e18_t2.pdf", format='pdf')
# plt.show()

# %%
# gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Twin/Twin_Finder_t2/Twin_State/Twin_t2_radius715").gf
# rb_had = gf_had.xy.fields.rho
# small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[10,10])
# rho_had =rb_had[0].to_UniformGridData_from_grid(small_grid)
# r_had=(rho_had.data_xyz)
# plt.figure(figsize=(30, 15))
# plt.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')
# plt.colorbar(label='Log Density')
# plt.xlabel('X', fontsize=20)
# plt.ylabel('Y', fontsize=20)

# x_ticks = np.arange(0, 10.1, 0.1)
# plt.xticks(x_ticks, rotation=90)
# plt.savefig("log_crmd_3.777874150828227e18_t2.pdf", format='pdf')
# plt.show()

# %%
# gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Twin/Twin_Finder_t2/Twin_State/Twin_t2_radius907").gf
# rb_had = gf_had.xy.fields.rho
# small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[10,10])
# rho_had =rb_had[0].to_UniformGridData_from_grid(small_grid)
# r_had=(rho_had.data_xyz)
# plt.figure(figsize=(30, 15))
# plt.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')
# plt.colorbar(label='Log Density')
# plt.xlabel('X', fontsize=20)
# plt.ylabel('Y', fontsize=20)

# x_ticks = np.arange(0, 10.1, 0.1)
# plt.xticks(x_ticks, rotation=90)
# #plt.savefig("log_cmrd_3.19799196172666957e18_t2.pdf", format='pdf')
# plt.show()

# %%
# gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Twin/Twin_Finder_t2/Twin_State/Twin_t2_radius1314").gf
# rb_had = gf_had.xy.fields.rho
# small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[10,10])
# rho_had =rb_had[0].to_UniformGridData_from_grid(small_grid)
# r_had=(rho_had.data_xyz)
# plt.figure(figsize=(30, 15))
# plt.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')
# plt.colorbar(label='Log Density')
# plt.xlabel('X', fontsize=20)
# plt.ylabel('Y', fontsize=20)

# x_ticks = np.arange(0, 10.1, 0.1)
# plt.xticks(x_ticks, rotation=90)
# #plt.savefig("log_crmd_3.1980518878365335e18_t2.pdf", format='pdf')
# plt.show()

# %%
# gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Twin/Twin_Finder_t2/Twin_State/Twin_t2_radius1363").gf
# rb_had = gf_had.xy.fields.rho
# small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[10,10])
# rho_had =rb_had[0].to_UniformGridData_from_grid(small_grid)
# r_had=(rho_had.data_xyz)
# plt.figure(figsize=(30, 15))
# plt.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')
# plt.colorbar(label='Log Density')
# plt.xlabel('X', fontsize=20)
# plt.ylabel('Y', fontsize=20)

# x_ticks = np.arange(0, 10.1, 0.1)
# plt.xticks(x_ticks, rotation=90)
# #plt.savefig("log_crmd_4.768982878365335e17_t2.pdf", format='pdf')
# plt.show()

# %%
# gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Twin_r5_radius13").gf
# rb_had = gf_had.xy.fields.rho
# small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[10,10])
# rho_had =rb_had[0].to_UniformGridData_from_grid(small_grid)
# r_had=(rho_had.data_xyz)
# plt.figure(figsize=(30, 15))
# plt.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')
# plt.colorbar(label='Log Density')
# plt.xlabel('X', fontsize=20)
# plt.ylabel('Y', fontsize=20)

# x_ticks = np.arange(0, 10.1, 0.1)
# plt.xticks(x_ticks, rotation=90)
# #plt.savefig("1.pdf", format='pdf')
# plt.show()

# %%
gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Twin_r5_radius13_static").gf
rb_had = gf_had.xy.fields.rho
small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[10,10])
rho_had =rb_had[0].to_UniformGridData_from_grid(small_grid)
r_had=(rho_had.data_xyz)
plt.figure(figsize=(30, 15))
plt.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')
plt.colorbar(label='Log Density')
plt.xlabel('X', fontsize=20)
plt.ylabel('Y', fontsize=20)

x_ticks = np.arange(0, 10.1, 0.1)
plt.xticks(x_ticks, rotation=90)
#plt.savefig("1.pdf", format='pdf')
plt.show()

# %%
gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Twin_r5_check_radius0000").gf
rb_had = gf_had.xy.fields.rho
small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[10,10])
rho_had =rb_had[0].to_UniformGridData_from_grid(small_grid)
r_had=(rho_had.data_xyz)
plt.figure(figsize=(30, 15))
plt.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')
plt.colorbar(label='Log Density')
plt.xlabel('X', fontsize=20)
plt.ylabel('Y', fontsize=20)

x_ticks = np.arange(0, 10.1, 0.1)
plt.xticks(x_ticks, rotation=90)
#plt.savefig("1.pdf", format='pdf')
plt.show()

# %%
gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Twin_r5_check_radius1000").gf
rb_had = gf_had.xy.fields.rho
small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[10,10])
rho_had =rb_had[0].to_UniformGridData_from_grid(small_grid)
r_had=(rho_had.data_xyz)
plt.figure(figsize=(30, 15))
plt.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')
plt.colorbar(label='Log Density')
plt.xlabel('X', fontsize=20)
plt.ylabel('Y', fontsize=20)

x_ticks = np.arange(0, 10.1, 0.1)
plt.xticks(x_ticks, rotation=90)
#plt.savefig("1.pdf", format='pdf')
plt.show()

r_had[0][0]

# %%
gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Twin_r5_check_radius1001").gf
rb_had = gf_had.xy.fields.rho
small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[12,12])
rho_had =rb_had[0].to_UniformGridData_from_grid(small_grid)
r_had=(rho_had.data_xyz)
plt.figure(figsize=(30, 15))
plt.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')
plt.colorbar(label='Log Density')
plt.xlabel('X', fontsize=20)
plt.ylabel('Y', fontsize=20)

x_ticks = np.arange(0, 12.1, 0.1)
plt.xticks(x_ticks, rotation=90)
#plt.savefig("1.pdf", format='pdf')
plt.show()

# %%
gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Twin_r5_check_radius1002").gf
rb_had = gf_had.xy.fields.rho
small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[10,10])
rho_had =rb_had[0].to_UniformGridData_from_grid(small_grid)
r_had=(rho_had.data_xyz)
plt.figure(figsize=(30, 15))
plt.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')
plt.colorbar(label='Log Density')
plt.xlabel('X', fontsize=20)
plt.ylabel('Y', fontsize=20)

x_ticks = np.arange(0, 10.1, 0.1)
plt.xticks(x_ticks, rotation=90)
#plt.savefig("1.pdf", format='pdf')
plt.show()

# %%
gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Twin_r5_check_radius1003").gf
rb_had = gf_had.xy.fields.rho
small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[10,10])
rho_had =rb_had[0].to_UniformGridData_from_grid(small_grid)
r_had=(rho_had.data_xyz)
plt.figure(figsize=(30, 15))
plt.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')
plt.colorbar(label='Log Density')
plt.xlabel('X', fontsize=20)
plt.ylabel('Y', fontsize=20)

x_ticks = np.arange(0, 10.1, 0.1)
plt.xticks(x_ticks, rotation=90)
#plt.savefig("1.pdf", format='pdf')
plt.show()

# %%
gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Twin_r5_check_radius1004").gf
rb_had = gf_had.xy.fields.rho
small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[10,10])
rho_had =rb_had[0].to_UniformGridData_from_grid(small_grid)
r_had=(rho_had.data_xyz)
plt.figure(figsize=(30, 15))
plt.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')
plt.colorbar(label='Log Density')
plt.xlabel('X', fontsize=20)
plt.ylabel('Y', fontsize=20)

x_ticks = np.arange(0, 10.1, 0.1)
plt.xticks(x_ticks, rotation=90)
#plt.savefig("1.pdf", format='pdf')
plt.show()

# %%
gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Twin_r5_check_radius1005").gf
rb_had = gf_had.xy.fields.rho
small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[10,10])
rho_had =rb_had[0].to_UniformGridData_from_grid(small_grid)
r_had=(rho_had.data_xyz)
plt.figure(figsize=(30, 15))
plt.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')
plt.colorbar(label='Log Density')
plt.xlabel('X', fontsize=20)
plt.ylabel('Y', fontsize=20)

x_ticks = np.arange(0, 10.1, 0.1)
plt.xticks(x_ticks, rotation=90)
#plt.savefig("1.pdf", format='pdf')
plt.show()

# %%
gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Twin_r5_check_radius1006").gf
rb_had = gf_had.xy.fields.rho
small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[10,10])
rho_had =rb_had[0].to_UniformGridData_from_grid(small_grid)
r_had=(rho_had.data_xyz)
plt.figure(figsize=(30, 15))
plt.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')
plt.colorbar(label='Log Density')
plt.xlabel('X', fontsize=20)
plt.ylabel('Y', fontsize=20)

x_ticks = np.arange(0, 10.1, 0.1)
plt.xticks(x_ticks, rotation=90)
#plt.savefig("1.pdf", format='pdf')
plt.show()

# %%
gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Twin_r5_check_radius1007").gf
rb_had = gf_had.xy.fields.rho
small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[10,10])
rho_had =rb_had[0].to_UniformGridData_from_grid(small_grid)
r_had=(rho_had.data_xyz)
plt.figure(figsize=(30, 15))
plt.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')
plt.colorbar(label='Log Density')
plt.xlabel('X', fontsize=20)
plt.ylabel('Y', fontsize=20)

x_ticks = np.arange(0, 10.1, 0.1)
plt.xticks(x_ticks, rotation=90)
#plt.savefig("1.pdf", format='pdf')
plt.show()
r_had[0][0]

# %%
gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Twin_r5_check_radius1008").gf
rb_had = gf_had.xy.fields.rho
small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[10,10])
rho_had =rb_had[0].to_UniformGridData_from_grid(small_grid)
r_had=(rho_had.data_xyz)
plt.figure(figsize=(30, 15))
plt.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')
plt.colorbar(label='Log Density')
plt.xlabel('X', fontsize=20)
plt.ylabel('Y', fontsize=20)

x_ticks = np.arange(0, 10.1, 0.1)
plt.xticks(x_ticks, rotation=90)
#plt.savefig("1.pdf", format='pdf')
plt.show()

# %%
gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Twin_r5_check_radius1009").gf
rb_had = gf_had.xy.fields.rho
small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[10,10])
rho_had =rb_had[0].to_UniformGridData_from_grid(small_grid)
r_had=(rho_had.data_xyz)
plt.figure(figsize=(30, 15))
plt.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')
plt.colorbar(label='Log Density')
plt.xlabel('X', fontsize=20)
plt.ylabel('Y', fontsize=20)

x_ticks = np.arange(0, 10.1, 0.1)
plt.xticks(x_ticks, rotation=90)
#plt.savefig("1.pdf", format='pdf')
plt.show()

# %%
gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Twin_r5_check_radius1010").gf
rb_had = gf_had.xy.fields.rho
small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[10,10])
rho_had =rb_had[0].to_UniformGridData_from_grid(small_grid)
r_had=(rho_had.data_xyz)
plt.figure(figsize=(30, 15))
plt.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')
plt.colorbar(label='Log Density')
plt.xlabel('X', fontsize=20)
plt.ylabel('Y', fontsize=20)

x_ticks = np.arange(0, 10.1, 0.1)
plt.xticks(x_ticks, rotation=90)
#plt.savefig("1.pdf", format='pdf')
plt.show()

# %%
gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Twin_r5_check_radius1011").gf
rb_had = gf_had.xy.fields.rho
small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[10,10])
rho_had =rb_had[0].to_UniformGridData_from_grid(small_grid)
r_had=(rho_had.data_xyz)
plt.figure(figsize=(30, 15))
plt.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')
plt.colorbar(label='Log Density')
plt.xlabel('X', fontsize=20)
plt.ylabel('Y', fontsize=20)

x_ticks = np.arange(0, 10.1, 0.1)
plt.xticks(x_ticks, rotation=90)
#plt.savefig("1.pdf", format='pdf')
plt.show()

# %%
gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Twin_r5_check_radius1012").gf
rb_had = gf_had.xy.fields.rho
small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[10,10])
rho_had =rb_had[0].to_UniformGridData_from_grid(small_grid)
r_had=(rho_had.data_xyz)
plt.figure(figsize=(30, 15))
plt.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')
plt.colorbar(label='Log Density')
plt.xlabel('X', fontsize=20)
plt.ylabel('Y', fontsize=20)

x_ticks = np.arange(0, 10.1, 0.1)
plt.xticks(x_ticks, rotation=90)
#plt.savefig("1.pdf", format='pdf')
plt.show()

# %%
gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Twin_r5_check_radius1013").gf
rb_had = gf_had.xy.fields.rho
small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[10,10])
rho_had =rb_had[0].to_UniformGridData_from_grid(small_grid)
r_had=(rho_had.data_xyz)
plt.figure(figsize=(30, 15))
plt.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')
plt.colorbar(label='Log Density')
plt.xlabel('X', fontsize=20)
plt.ylabel('Y', fontsize=20)

x_ticks = np.arange(0, 10.1, 0.1)
plt.xticks(x_ticks, rotation=90)
#plt.savefig("1.pdf", format='pdf')
plt.show()

# %%
gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Twin_r5_check_radius1000").gf
rb_had = gf_had.xy.fields.rho
small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[10,10])
rho_had =rb_had[0].to_UniformGridData_from_grid(small_grid)
r_had=(rho_had.data_xyz)

plt.plot(np.log10(r_had[0]))

gf_had2 = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Twin_r5_check_radius1008").gf
rb_had2 = gf_had2.xy.fields.rho
small_grid2 = UniformGrid([500, 500], x0=[0, 0], x1=[10,10])
rho_had2 =rb_had2[0].to_UniformGridData_from_grid(small_grid2)
r_had2=(rho_had2.data_xyz)

plt.plot(np.log10(r_had2[0]))

# %%
gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Time Evolution/Grid2/Twin_r5_11").gf
rb_had = gf_had.xy.fields.rho
small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[10,10])
rho_had =rb_had[0].to_UniformGridData_from_grid(small_grid)
r_had=(rho_had.data_xyz)
plt.figure(figsize=(30, 15))
plt.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')
plt.colorbar(label='Log Density')
plt.xlabel('X', fontsize=20)
plt.ylabel('Y', fontsize=20)
print(rb_had.iterations)
x_ticks = np.arange(0, 10.1, 0.1)
plt.xticks(x_ticks, rotation=90)
plt.savefig("r5_A.pdf", format='pdf')
plt.show()

gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Time Evolution/Grid2/Twin_r5_12").gf
rb_had = gf_had.xy.fields.rho
small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[10,10])
rho_had =rb_had[0].to_UniformGridData_from_grid(small_grid)
r_had=(rho_had.data_xyz)
plt.figure(figsize=(30, 15))
plt.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')
plt.colorbar(label='Log Density')
plt.xlabel('X', fontsize=20)
plt.ylabel('Y', fontsize=20)
print(rb_had.iterations)
x_ticks = np.arange(0, 10.1, 0.1)
plt.xticks(x_ticks, rotation=90)
plt.savefig("r5_B.pdf", format='pdf')
plt.show()

gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Time Evolution/Grid2/Twin_r5_13").gf
rb_had = gf_had.xy.fields.rho
small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[10,10])
rho_had =rb_had[0].to_UniformGridData_from_grid(small_grid)
r_had=(rho_had.data_xyz)
plt.figure(figsize=(30, 15))
plt.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')
plt.colorbar(label='Log Density')
plt.xlabel('X', fontsize=20)
plt.ylabel('Y', fontsize=20)

x_ticks = np.arange(0, 10.1, 0.1)
plt.xticks(x_ticks, rotation=90)
plt.savefig("r5_C.pdf", format='pdf')
plt.show()


gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Time Evolution/Grid2/Twin_t2_7").gf
rb_had = gf_had.xy.fields.rho
small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[10,10])
rho_had =rb_had[0].to_UniformGridData_from_grid(small_grid)
r_had=(rho_had.data_xyz)
plt.figure(figsize=(30, 15))
plt.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')
plt.colorbar(label='Log Density')
plt.xlabel('X', fontsize=20)
plt.ylabel('Y', fontsize=20)

x_ticks = np.arange(0, 10.1, 0.1)
plt.xticks(x_ticks, rotation=90)
plt.savefig("t2_A.pdf", format='pdf')
plt.show()

gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Time Evolution/Grid2/Twin_t2_8").gf
rb_had = gf_had.xy.fields.rho
small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[10,10])
rho_had =rb_had[0].to_UniformGridData_from_grid(small_grid)
r_had=(rho_had.data_xyz)
plt.figure(figsize=(30, 15))
plt.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')
plt.colorbar(label='Log Density')
plt.xlabel('X', fontsize=20)
plt.ylabel('Y', fontsize=20)

x_ticks = np.arange(0, 10.1, 0.1)
plt.xticks(x_ticks, rotation=90)
plt.savefig("t2_B.pdf", format='pdf')
plt.show()

gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Time Evolution/Grid2/Twin_t2_9").gf
rb_had = gf_had.xy.fields.rho
small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[10,10])
rho_had =rb_had[0].to_UniformGridData_from_grid(small_grid)
r_had=(rho_had.data_xyz)
plt.figure(figsize=(30, 15))
plt.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')
plt.colorbar(label='Log Density')
plt.xlabel('X', fontsize=20)
plt.ylabel('Y', fontsize=20)

x_ticks = np.arange(0, 10.1, 0.1)
plt.xticks(x_ticks, rotation=90)
plt.savefig("t2_C.pdf", format='pdf')
plt.show()

gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Time Evolution/Grid2/Twin_t2_13").gf
rb_had = gf_had.xy.fields.rho
small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[10,10])
rho_had =rb_had[0].to_UniformGridData_from_grid(small_grid)
r_had=(rho_had.data_xyz)
plt.figure(figsize=(30, 15))
plt.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')
plt.colorbar(label='Log Density')
plt.xlabel('X', fontsize=20)
plt.ylabel('Y', fontsize=20)

x_ticks = np.arange(0, 10.1, 0.1)
plt.xticks(x_ticks, rotation=90)
plt.savefig("t2_D.pdf", format='pdf')
plt.show()

# %%
gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Time Evolution/Grid2/Twin_r5_11").gf
rb_had = gf_had.xy.fields.rho
small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[15,15])
rho_had =rb_had[54016].to_UniformGridData_from_grid(small_grid)
r_had=(rho_had.data_xyz)
plt.figure(figsize=(30, 15))
plt.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')
plt.colorbar(label='Log Density')
plt.xlabel('X', fontsize=20)
plt.ylabel('Y', fontsize=20)
print(rb_had.iterations)
x_ticks = np.arange(0, 15.1, 0.1)
plt.xticks(x_ticks, rotation=90)
plt.savefig("r5_A.pdf", format='pdf')
plt.show()
# Out:
# [0, 128, 256, 384, 512, 640, 768, 896, 1024, 1152, 1280, 1408, 1536, 1664, 1792, 1920, 2048, 2176, 2304, 2432, 2560, 2688, 2816, 2944, 3072, 3200, 3328, 3456, 3584, 3712, 3840, 3968, 4096, 4224, 4352, 4480, 4608, 4736, 4864, 4992, 5120, 5248, 5376, 5504, 5632, 5760, 5888, 6016, 6144, 6272, 6400, 6528, 6656, 6784, 6912, 7040, 7168, 7296, 7424, 7552, 7680, 7808, 7936, 8064, 8192, 8320, 8448, 8576, 8704, 8832, 8960, 9088, 9216, 9344, 9472, 9600, 9728, 9856, 9984, 10112, 10240, 10368, 10496, 10624, 10752, 10880, 11008, 11136, 11264, 11392, 11520, 11648, 11776, 11904, 12032, 12160, 12288, 12416, 12544, 12672, 12800, 12928, 13056, 13184, 13312, 13440, 13568, 13696, 13824, 13952, 14080, 14208, 14336, 14464, 14592, 14720, 14848, 14976, 15104, 15232, 15360, 15488, 15616, 15744, 15872, 16000, 16128, 16256, 16384, 16512, 16640, 16768, 16896, 17024, 17152, 17280, 17408, 17536, 17664, 17792, 17920, 18048, 18176, 18304, 18432, 18560, 18688, 18816, 18944, 19072, 19200, 19328, 19456, 19584, 19712, 1
# ...

# %%
gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Time Evolution/Grid2/Twin_r5_12").gf
rb_had = gf_had.xy.fields.rho
small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[15,15])
rho_had =rb_had[54016].to_UniformGridData_from_grid(small_grid)
r_had=(rho_had.data_xyz)
plt.figure(figsize=(30, 15))
plt.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')
plt.colorbar(label='Log Density')
plt.xlabel('X', fontsize=20)
plt.ylabel('Y', fontsize=20)
print(rb_had.iterations)
x_ticks = np.arange(0, 15.1, 0.1)
plt.xticks(x_ticks, rotation=90)
plt.savefig("r5_B.pdf", format='pdf')
plt.show()
# Out:
# [0, 128, 256, 384, 512, 640, 768, 896, 1024, 1152, 1280, 1408, 1536, 1664, 1792, 1920, 2048, 2176, 2304, 2432, 2560, 2688, 2816, 2944, 3072, 3200, 3328, 3456, 3584, 3712, 3840, 3968, 4096, 4224, 4352, 4480, 4608, 4736, 4864, 4992, 5120, 5248, 5376, 5504, 5632, 5760, 5888, 6016, 6144, 6272, 6400, 6528, 6656, 6784, 6912, 7040, 7168, 7296, 7424, 7552, 7680, 7808, 7936, 8064, 8192, 8320, 8448, 8576, 8704, 8832, 8960, 9088, 9216, 9344, 9472, 9600, 9728, 9856, 9984, 10112, 10240, 10368, 10496, 10624, 10752, 10880, 11008, 11136, 11264, 11392, 11520, 11648, 11776, 11904, 12032, 12160, 12288, 12416, 12544, 12672, 12800, 12928, 13056, 13184, 13312, 13440, 13568, 13696, 13824, 13952, 14080, 14208, 14336, 14464, 14592, 14720, 14848, 14976, 15104, 15232, 15360, 15488, 15616, 15744, 15872, 16000, 16128, 16256, 16384, 16512, 16640, 16768, 16896, 17024, 17152, 17280, 17408, 17536, 17664, 17792, 17920, 18048, 18176, 18304, 18432, 18560, 18688, 18816, 18944, 19072, 19200, 19328, 19456, 19584, 19712, 1
# ...

# %%
gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Time Evolution/Grid2/Twin_r5_13").gf
rb_had = gf_had.xy.fields.rho
small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[15,15])
rho_had =rb_had[54016].to_UniformGridData_from_grid(small_grid)
r_had=(rho_had.data_xyz)
print(rb_had.iterations)
plt.figure(figsize=(30, 15))
plt.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')
plt.colorbar(label='Log Density')
plt.xlabel('X', fontsize=20)
plt.ylabel('Y', fontsize=20)
x_ticks = np.arange(0, 15.1, 0.1)
plt.xticks(x_ticks, rotation=90)
plt.savefig("r5_C.pdf", format='pdf')
plt.show()
# Out:
# [0, 128, 256, 384, 512, 640, 768, 896, 1024, 1152, 1280, 1408, 1536, 1664, 1792, 1920, 2048, 2176, 2304, 2432, 2560, 2688, 2816, 2944, 3072, 3200, 3328, 3456, 3584, 3712, 3840, 3968, 4096, 4224, 4352, 4480, 4608, 4736, 4864, 4992, 5120, 5248, 5376, 5504, 5632, 5760, 5888, 6016, 6144, 6272, 6400, 6528, 6656, 6784, 6912, 7040, 7168, 7296, 7424, 7552, 7680, 7808, 7936, 8064, 8192, 8320, 8448, 8576, 8704, 8832, 8960, 9088, 9216, 9344, 9472, 9600, 9728, 9856, 9984, 10112, 10240, 10368, 10496, 10624, 10752, 10880, 11008, 11136, 11264, 11392, 11520, 11648, 11776, 11904, 12032, 12160, 12288, 12416, 12544, 12672, 12800, 12928, 13056, 13184, 13312, 13440, 13568, 13696, 13824, 13952, 14080, 14208, 14336, 14464, 14592, 14720, 14848, 14976, 15104, 15232, 15360, 15488, 15616, 15744, 15872, 16000, 16128, 16256, 16384, 16512, 16640, 16768, 16896, 17024, 17152, 17280, 17408, 17536, 17664, 17792, 17920, 18048, 18176, 18304, 18432, 18560, 18688, 18816, 18944, 19072, 19200, 19328, 19456, 19584, 19712, 1
# ...

# %%
gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Time Evolution/Grid2/Twin_t2_7").gf
rb_had = gf_had.xy.fields.rho
small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[15,15])
rho_had =rb_had[54016].to_UniformGridData_from_grid(small_grid)
r_had=(rho_had.data_xyz)
print(rb_had.iterations)
plt.figure(figsize=(30, 15))
plt.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')
plt.colorbar(label='Log Density')
plt.xlabel('X', fontsize=20)
plt.ylabel('Y', fontsize=20)

x_ticks = np.arange(0, 15.1, 0.1)
plt.xticks(x_ticks, rotation=90)
plt.savefig("t2_A.pdf", format='pdf')
plt.show()
# Out:
# [0, 128, 256, 384, 512, 640, 768, 896, 1024, 1152, 1280, 1408, 1536, 1664, 1792, 1920, 2048, 2176, 2304, 2432, 2560, 2688, 2816, 2944, 3072, 3200, 3328, 3456, 3584, 3712, 3840, 3968, 4096, 4224, 4352, 4480, 4608, 4736, 4864, 4992, 5120, 5248, 5376, 5504, 5632, 5760, 5888, 6016, 6144, 6272, 6400, 6528, 6656, 6784, 6912, 7040, 7168, 7296, 7424, 7552, 7680, 7808, 7936, 8064, 8192, 8320, 8448, 8576, 8704, 8832, 8960, 9088, 9216, 9344, 9472, 9600, 9728, 9856, 9984, 10112, 10240, 10368, 10496, 10624, 10752, 10880, 11008, 11136, 11264, 11392, 11520, 11648, 11776, 11904, 12032, 12160, 12288, 12416, 12544, 12672, 12800, 12928, 13056, 13184, 13312, 13440, 13568, 13696, 13824, 13952, 14080, 14208, 14336, 14464, 14592, 14720, 14848, 14976, 15104, 15232, 15360, 15488, 15616, 15744, 15872, 16000, 16128, 16256, 16384, 16512, 16640, 16768, 16896, 17024, 17152, 17280, 17408, 17536, 17664, 17792, 17920, 18048, 18176, 18304, 18432, 18560, 18688, 18816, 18944, 19072, 19200, 19328, 19456, 19584, 19712, 1
# ...

# %%
gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Time Evolution/Grid2/Twin_t2_8").gf
rb_had = gf_had.xy.fields.rho
small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[15,15])
rho_had =rb_had[54016].to_UniformGridData_from_grid(small_grid)
r_had=(rho_had.data_xyz)
print(rb_had.iterations)
plt.figure(figsize=(30, 15))
plt.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')
plt.colorbar(label='Log Density')
plt.xlabel('X', fontsize=20)
plt.ylabel('Y', fontsize=20)
x_ticks = np.arange(0, 15.1, 0.1)
plt.xticks(x_ticks, rotation=90)
plt.savefig("t2_B.pdf", format='pdf')
plt.show()
# Out:
# [0, 128, 256, 384, 512, 640, 768, 896, 1024, 1152, 1280, 1408, 1536, 1664, 1792, 1920, 2048, 2176, 2304, 2432, 2560, 2688, 2816, 2944, 3072, 3200, 3328, 3456, 3584, 3712, 3840, 3968, 4096, 4224, 4352, 4480, 4608, 4736, 4864, 4992, 5120, 5248, 5376, 5504, 5632, 5760, 5888, 6016, 6144, 6272, 6400, 6528, 6656, 6784, 6912, 7040, 7168, 7296, 7424, 7552, 7680, 7808, 7936, 8064, 8192, 8320, 8448, 8576, 8704, 8832, 8960, 9088, 9216, 9344, 9472, 9600, 9728, 9856, 9984, 10112, 10240, 10368, 10496, 10624, 10752, 10880, 11008, 11136, 11264, 11392, 11520, 11648, 11776, 11904, 12032, 12160, 12288, 12416, 12544, 12672, 12800, 12928, 13056, 13184, 13312, 13440, 13568, 13696, 13824, 13952, 14080, 14208, 14336, 14464, 14592, 14720, 14848, 14976, 15104, 15232, 15360, 15488, 15616, 15744, 15872, 16000, 16128, 16256, 16384, 16512, 16640, 16768, 16896, 17024, 17152, 17280, 17408, 17536, 17664, 17792, 17920, 18048, 18176, 18304, 18432, 18560, 18688, 18816, 18944, 19072, 19200, 19328, 19456, 19584, 19712, 1
# ...

# %%
gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Time Evolution/Grid2/Twin_t2_9").gf
rb_had = gf_had.xy.fields.rho
small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[15,15])
rho_had =rb_had[54016].to_UniformGridData_from_grid(small_grid)
r_had=(rho_had.data_xyz)
print(rb_had.iterations)
plt.figure(figsize=(30, 15))
plt.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')
plt.colorbar(label='Log Density')
plt.xlabel('X', fontsize=20)
plt.ylabel('Y', fontsize=20)
x_ticks = np.arange(0, 15.1, 0.1)
plt.xticks(x_ticks, rotation=90)
plt.savefig("t2_C.pdf", format='pdf')
plt.show()
# Out:
# [0, 128, 256, 384, 512, 640, 768, 896, 1024, 1152, 1280, 1408, 1536, 1664, 1792, 1920, 2048, 2176, 2304, 2432, 2560, 2688, 2816, 2944, 3072, 3200, 3328, 3456, 3584, 3712, 3840, 3968, 4096, 4224, 4352, 4480, 4608, 4736, 4864, 4992, 5120, 5248, 5376, 5504, 5632, 5760, 5888, 6016, 6144, 6272, 6400, 6528, 6656, 6784, 6912, 7040, 7168, 7296, 7424, 7552, 7680, 7808, 7936, 8064, 8192, 8320, 8448, 8576, 8704, 8832, 8960, 9088, 9216, 9344, 9472, 9600, 9728, 9856, 9984, 10112, 10240, 10368, 10496, 10624, 10752, 10880, 11008, 11136, 11264, 11392, 11520, 11648, 11776, 11904, 12032, 12160, 12288, 12416, 12544, 12672, 12800, 12928, 13056, 13184, 13312, 13440, 13568, 13696, 13824, 13952, 14080, 14208, 14336, 14464, 14592, 14720, 14848, 14976, 15104, 15232, 15360, 15488, 15616, 15744, 15872, 16000, 16128, 16256, 16384, 16512, 16640, 16768, 16896, 17024, 17152, 17280, 17408, 17536, 17664, 17792, 17920, 18048, 18176, 18304, 18432, 18560, 18688, 18816, 18944, 19072, 19200, 19328, 19456, 19584, 19712, 1
# ...

# %%
gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Time Evolution/Grid2/Twin_t2_13").gf
rb_had = gf_had.xy.fields.rho
small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[15,15])
rho_had =rb_had[54016].to_UniformGridData_from_grid(small_grid)
r_had=(rho_had.data_xyz)
print(rb_had.iterations)
plt.figure(figsize=(30, 15))
plt.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')
plt.colorbar(label='Log Density')
plt.xlabel('X', fontsize=20)
plt.ylabel('Y', fontsize=20)
x_ticks = np.arange(0, 15.1, 0.1)
plt.xticks(x_ticks, rotation=90)
plt.savefig("t2_D.pdf", format='pdf')
plt.show()
# Out:
# [0, 128, 256, 384, 512, 640, 768, 896, 1024, 1152, 1280, 1408, 1536, 1664, 1792, 1920, 2048, 2176, 2304, 2432, 2560, 2688, 2816, 2944, 3072, 3200, 3328, 3456, 3584, 3712, 3840, 3968, 4096, 4224, 4352, 4480, 4608, 4736, 4864, 4992, 5120, 5248, 5376, 5504, 5632, 5760, 5888, 6016, 6144, 6272, 6400, 6528, 6656, 6784, 6912, 7040, 7168, 7296, 7424, 7552, 7680, 7808, 7936, 8064, 8192, 8320, 8448, 8576, 8704, 8832, 8960, 9088, 9216, 9344, 9472, 9600, 9728, 9856, 9984, 10112, 10240, 10368, 10496, 10624, 10752, 10880, 11008, 11136, 11264, 11392, 11520, 11648, 11776, 11904, 12032, 12160, 12288, 12416, 12544, 12672, 12800, 12928, 13056, 13184, 13312, 13440, 13568, 13696, 13824, 13952, 14080, 14208, 14336, 14464, 14592, 14720, 14848, 14976, 15104, 15232, 15360, 15488, 15616, 15744, 15872, 16000, 16128, 16256, 16384, 16512, 16640, 16768, 16896, 17024, 17152, 17280, 17408, 17536, 17664, 17792, 17920, 18048, 18176, 18304, 18432, 18560, 18688, 18816, 18944, 19072, 19200, 19328, 19456, 19584, 19712, 1
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import os

# Use your home directory or another directory where you have write access
save_dir = "/home/ron_mukherjee/Documents/simulation_plots"
os.makedirs(save_dir, exist_ok=True)

# List to store the file paths of the saved images
image_paths = []

# Iterate over the iterations and create plots
for i, iteration in enumerate(rb_had.iterations):
    # Get the corresponding data for the iteration
    rho_had = rb_had[iteration].to_UniformGridData_from_grid(small_grid)
    r_had = rho_had.data_xyz

    # Plot the data
    plt.figure(figsize=(10, 5))
    plt.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')
    plt.colorbar(label='Log Density')
    plt.xlabel('X')
    plt.ylabel('Y')

    # Save the plot as an image
    image_path = os.path.join(save_dir, f"plot_{i:04d}.png")
    plt.savefig(image_path, format='png')
    plt.close()
    
    # Append the image path to the list
    image_paths.append(image_path)

# Create a GIF from the images
gif_path = os.path.join(save_dir, "t2_D_animation.gif")
images = [Image.open(image_path) for image_path in image_paths]
images[0].save(gif_path, save_all=True, append_images=images[1:], duration=100, loop=0)

print(f"GIF saved at {gif_path}")
# Out:
# GIF saved at /home/ron_mukherjee/Documents/simulation_plots/t2_D_animation.gif

# %%
gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Twin_t2_7").gf
rb_had = gf_had.xy.fields.rho
small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[15,15])
rho_had =rb_had[54016].to_UniformGridData_from_grid(small_grid)
r_had=(rho_had.data_xyz)
plt.figure(figsize=(30, 15))
plt.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')
plt.colorbar(label='Log Density')
plt.xlabel('X', fontsize=20)
plt.ylabel('Y', fontsize=20)
#print(rb_had.iterations)
x_ticks = np.arange(0, 15.1, 0.5)
plt.xticks(x_ticks, rotation=90)
#plt.savefig("twint2_54016iteration.pdf", format='pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.axes_grid1 import make_axes_locatable

gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Twin_t2_7").gf
rb_had = gf_had.xy.fields.rho
small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[15,15])
rho_had =rb_had[54016].to_UniformGridData_from_grid(small_grid)
r_had=(rho_had.data_xyz)


plt.figure(figsize=(30, 30))
ax = plt.gca()
pcm = ax.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')

# Set axis labels with larger font size
plt.xlabel('X', fontsize=30)
plt.ylabel('Y', fontsize=30)

# Set tick labels with larger font size
x_ticks = np.arange(0, 15.1, 0.5)
plt.xticks(x_ticks, rotation=90, fontsize=30)
plt.yticks(fontsize=30)

# Ensure the plot is square-shaped
ax.set_aspect('equal', adjustable='box')

# Create a divider for existing axes instance
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)

# Create the colorbar with the same height as the plot
cbar = plt.colorbar(pcm, cax=cax)
cbar.set_label('Log Density', fontsize=30)
cbar.ax.tick_params(labelsize=30)

# Save and display the plot
plt.savefig("twint2_0iteration.pdf", format='pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Step 1: Create the x and y coordinate arrays
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)

# Step 2: Create a meshgrid from the coordinate arrays
X, Y = np.meshgrid(x, y)

# Step 3: Define a function to generate z values
Z = np.sin(np.sqrt(X**2 + Y**2))

# Step 4: Create a contour plot
plt.figure(figsize=(10, 5))

# Standard Contour Plot
plt.subplot(1, 2, 1)
contour = plt.contour(X, Y, Z, levels=10, colors='black')
plt.clabel(contour, inline=True, fontsize=8)
plt.title('Contour Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# Step 5: Create a filled contour plot
plt.subplot(1, 2, 2)
contourf = plt.contourf(X, Y, Z, levels=10, cmap='viridis')
plt.colorbar(contourf)
plt.title('Filled Contour Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# Show the plots
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.axes_grid1 import make_axes_locatable

# Constants
rho_0 = 2.7e17  # Nuclear saturation density in kg/m^3
threshold_density = 0.01 * rho_0  # Threshold density

# Load data
gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Twin_t2_7").gf
rb_had = gf_had.xy.fields.rho
small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[15, 15])
rho_had = rb_had[54016].to_UniformGridData_from_grid(small_grid)
r_had = rho_had.data_xyz

plt.figure(figsize=(30, 30))
ax = plt.gca()
rho_0 = 2.5e14 / (6.17627e17) # Nuclear saturation density in kg/m^3
threshold_density_1 = np.log10(0.01 * rho_0)
threshold_density_2 = np.log10(0.1 * rho_0)
threshold_density_3 = np.log10(rho_0)

# Create a contour plot only at the threshold density
contour = ax.contour(*rho_had.coordinates_meshgrid(), np.log10(r_had), levels=[threshold_density_1, threshold_density_2, threshold_density_3], colors='blue')

# Plot the pcolormesh
pcm = ax.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')

# Set axis labels with larger font size
plt.xlabel('X', fontsize=30)
plt.ylabel('Y', fontsize=30)

# Set tick labels with larger font size
x_ticks = np.arange(0, 15.1, 0.5)
plt.xticks(x_ticks, rotation=90, fontsize=30)
plt.yticks(fontsize=30)

# Ensure the plot is square-shaped
ax.set_aspect('equal', adjustable='box')

# Create a divider for existing axes instance
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)

# Create the colorbar with the same height as the plot
cbar = plt.colorbar(pcm, cax=cax)
cbar.set_label('Log Density', fontsize=30)
cbar.ax.tick_params(labelsize=30)

# Overlay the contour for density less than 0.01 rho_0
contour_levels = [np.log10(threshold_density)]  # Level at threshold density
contour = ax.contour(*rho_had.coordinates_meshgrid(), np.log10(r_had), levels=contour_levels, colors='red', linewidths=2)

# Add label for the contour
ax.clabel(contour, fmt={contour_levels[0]: '0.01 ρ₀'}, fontsize=20, colors='red')

# Save and display the plot
#plt.savefig("twint2_0iteration_with_contour.pdf", format='pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.axes_grid1 import make_axes_locatable

# Load data
gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Twin_t2_7").gf
rb_had = gf_had.xy.fields.rho
small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[15, 15])
rho_had = rb_had[54016].to_UniformGridData_from_grid(small_grid)
r_had = rho_had.data_xyz

plt.figure(figsize=(30, 30))
ax = plt.gca()

# Create a contour plot
contour_levels = np.linspace(np.log10(r_had.min()), np.log10(r_had.max()), 10)  # Define contour levels
contour = ax.contour(*rho_had.coordinates_meshgrid(), np.log10(r_had), levels=contour_levels, cmap='viridis')

#contour_levels = np.linspace(r_had.min(), r_had.max(), 30)  # Define contour levels
#contour = ax.contour(*rho_had.coordinates_meshgrid(), r_had, levels=contour_levels, cmap='viridis')

# Add labels to contours
ax.clabel(contour, inline=True, fontsize=20)

# Set axis labels with larger font size
plt.xlabel('X', fontsize=30)
plt.ylabel('Y', fontsize=30)

# Set tick labels with larger font size
x_ticks = np.arange(0, 15.1, 0.5)
plt.xticks(x_ticks, rotation=90, fontsize=30)
plt.yticks(fontsize=30)

# Ensure the plot is square-shaped
ax.set_aspect('equal', adjustable='box')

# Create a divider for existing axes instance
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)

# Create the colorbar with the same height as the plot
cbar = plt.colorbar(contour, cax=cax)
cbar.set_label('Log Density', fontsize=30)
cbar.ax.tick_params(labelsize=30)

# Save and display the plot
#plt.savefig("twint2_54016_contour_iteration.pdf", format='pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.axes_grid1 import make_axes_locatable

# Constants
rho_0 = 2.5e14 / (6.17627e17)  # Nuclear saturation density in kg/m^3
threshold_density = 0.01 * rho_0  # Threshold density

print(np.log10(threshold_density))
# Out:
# -5.392786264560279

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.axes_grid1 import make_axes_locatable

# Load data
gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Twin_t2_7").gf
rb_had = gf_had.xy.fields.rho
small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[15, 15])
rho_had = rb_had[54016].to_UniformGridData_from_grid(small_grid)
r_had = rho_had.data_xyz

plt.figure(figsize=(30, 30))
ax = plt.gca()

# Define threshold density
rho_0 = 2.5e14 / (6.17627e17) # Nuclear saturation density in kg/m^3
threshold_density = 0.01 * rho_0

# Create a contour plot only at the threshold density
contour = ax.contour(*rho_had.coordinates_meshgrid(), r_had, levels=[threshold_density], colors='blue')

# Add labels to contours
ax.clabel(contour, inline=True, fontsize=20)

# Set axis labels with larger font size
plt.xlabel('X', fontsize=30)
plt.ylabel('Y', fontsize=30)

# Set tick labels with larger font size
x_ticks = np.arange(0, 15.1, 0.5)
plt.xticks(x_ticks, rotation=90, fontsize=30)
plt.yticks(fontsize=30)

# Ensure the plot is square-shaped
ax.set_aspect('equal', adjustable='box')

# Create a divider for existing axes instance
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)

# Create the colorbar with the same height as the plot
cbar = plt.colorbar(contour, cax=cax)
cbar.set_label('Density', fontsize=30)  # You can change this to Log Density if using log scale
cbar.ax.tick_params(labelsize=30)

# Save and display the plot
#plt.savefig("twint2_54016_contour_iteration.pdf", format='pdf')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 42
#      39 cax = divider.append_axes("right", size="5%", pad=0.1)
#      41 # Create the colorbar with the same height as the plot
# ---> 42 cbar = plt.colorbar(contour, cax=cax)
#      43 cbar.set_label('Density', fontsize=30)  # You can change this to Log Density if using log scale
#      44 cbar.ax.tick_params(labelsize=30)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/pyplot.py:2516, in colorbar(mappable, cax, ax, **kwargs)
#    2511     if mappable is None:
#    2512         raise RuntimeError('No mappable was found to use for colorbar '
#    2513                            'creation. First define a mappable such as '
#    2514                            'an image (with imshow) or a contour set ('
#    2515                            'with contourf).')
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.axes_grid1 import make_axes_locatable

# Constants
rho_0 = 2.7e17  # Nuclear saturation density in kg/m^3
threshold_density = 0.01 * rho_0  # Threshold density

# Load data
gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Time Evolution/Grid2/Twin_t2_8").gf
rb_had = gf_had.xy.fields.rho
small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[15, 15])
rho_had = rb_had[54016].to_UniformGridData_from_grid(small_grid)
r_had = rho_had.data_xyz

plt.figure(figsize=(30, 30))
ax = plt.gca()
rho_0 = 2.5e14 / (6.17627e17) # Nuclear saturation density in kg/m^3
threshold_density_1 = np.log10(0.01 * rho_0)
threshold_density_2 = np.log10(0.1 * rho_0)
threshold_density_3 = np.log10(rho_0)

# Create a contour plot only at the threshold density
contour = ax.contour(*rho_had.coordinates_meshgrid(), np.log10(r_had), levels=[threshold_density_1, threshold_density_2, threshold_density_3], colors='blue')

# Plot the pcolormesh
pcm = ax.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')

# Set axis labels with larger font size
plt.xlabel('X', fontsize=30)
plt.ylabel('Y', fontsize=30)

# Set tick labels with larger font size
x_ticks = np.arange(0, 15.1, 0.5)
plt.xticks(x_ticks, rotation=90, fontsize=30)
plt.yticks(fontsize=30)

# Ensure the plot is square-shaped
ax.set_aspect('equal', adjustable='box')

# Create a divider for existing axes instance
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)

# Create the colorbar with the same height as the plot
cbar = plt.colorbar(pcm, cax=cax)
cbar.set_label('Log Density', fontsize=30)
cbar.ax.tick_params(labelsize=30)

# Overlay the contour for density less than 0.01 rho_0
contour_levels = [np.log10(threshold_density)]  # Level at threshold density
contour = ax.contour(*rho_had.coordinates_meshgrid(), np.log10(r_had), levels=contour_levels, colors='red', linewidths=2)

# Add label for the contour
ax.clabel(contour, fmt={contour_levels[0]: '0.01 ρ₀'}, fontsize=20, colors='red')

# Save and display the plot
#plt.savefig("twint2_0iteration_with_contour.pdf", format='pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.axes_grid1 import make_axes_locatable

# Constants
rho_0 = 2.7e17  # Nuclear saturation density in kg/m^3
threshold_density = 0.01 * rho_0  # Threshold density

# Load data
gf_had = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Time Evolution/Grid2/Twin_t2_13").gf
rb_had = gf_had.xy.fields.rho
small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[15, 15])
rho_had = rb_had[54016].to_UniformGridData_from_grid(small_grid)
r_had = rho_had.data_xyz

plt.figure(figsize=(30, 30))
ax = plt.gca()
rho_0 = 2.5e14 / (6.17627e17) # Nuclear saturation density in kg/m^3
threshold_density_1 = np.log10(0.01 * rho_0)
threshold_density_2 = np.log10(0.1 * rho_0)
threshold_density_3 = np.log10(rho_0)

# Create a contour plot only at the threshold density
contour = ax.contour(*rho_had.coordinates_meshgrid(), np.log10(r_had), levels=[threshold_density_1, threshold_density_2, threshold_density_3], colors='blue')

# Plot the pcolormesh
pcm = ax.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')

# Set axis labels with larger font size
plt.xlabel('X', fontsize=30)
plt.ylabel('Y', fontsize=30)

# Set tick labels with larger font size
x_ticks = np.arange(0, 15.1, 0.5)
plt.xticks(x_ticks, rotation=90, fontsize=30)
plt.yticks(fontsize=30)

# Ensure the plot is square-shaped
ax.set_aspect('equal', adjustable='box')

# Create a divider for existing axes instance
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)

# Create the colorbar with the same height as the plot
cbar = plt.colorbar(pcm, cax=cax)
cbar.set_label('Log Density', fontsize=30)
cbar.ax.tick_params(labelsize=30)

# Overlay the contour for density less than 0.01 rho_0
contour_levels = [np.log10(threshold_density)]  # Level at threshold density
contour = ax.contour(*rho_had.coordinates_meshgrid(), np.log10(r_had), levels=contour_levels, colors='red', linewidths=2)

# Add label for the contour
ax.clabel(contour, fmt={contour_levels[0]: '0.01 ρ₀'}, fontsize=20, colors='red')

# Save and display the plot
#plt.savefig("twint2_0iteration_with_contour.pdf", format='pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.axes_grid1 import make_axes_locatable

# Constants
rho_0 = 2.7e17  # Nuclear saturation density in kg/m^3
threshold_density = 0.01 * rho_0  # Threshold density

# Paths to different simulation directories
simulation_paths = [
    "/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Time Evolution/Grid2/Twin_t2_7",
    "/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Time Evolution/Grid2/Twin_t2_8",
    "/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Time Evolution/Grid2/Twin_t2_9",
    "/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Time Evolution/Grid2/Twin_t2_13"
]

# Plot setup
fig, axs = plt.subplots(1, 4, figsize=(60, 30))  # Create a 1x4 subplot

# Iterate through each simulation path and plot
for i, sim_path in enumerate(simulation_paths):
    gf_had = SimDir(sim_path).gf
    rb_had = gf_had.xy.fields.rho
    small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[15, 15])
    rho_had = rb_had[54016].to_UniformGridData_from_grid(small_grid)
    r_had = rho_had.data_xyz

    ax = axs[i]  # Select the correct subplot axis
    rho_0 = 2.5e14 / (6.17627e17)  # Nuclear saturation density in kg/m^3
    threshold_density_1 = np.log10(0.01 * rho_0)
    threshold_density_2 = np.log10(0.1 * rho_0)
    threshold_density_3 = np.log10(rho_0)

    # Create a contour plot only at the threshold density
    ax.contour(*rho_had.coordinates_meshgrid(), np.log10(r_had), levels=[threshold_density_1, threshold_density_2, threshold_density_3], colors='blue')

    # Plot the pcolormesh
    pcm = ax.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')

    # Set axis labels with larger font size
    ax.set_xlabel('X', fontsize=30)
    ax.set_ylabel('Y', fontsize=30)

    # Set tick labels with larger font size
    x_ticks = np.arange(0, 15.1, 1)
    ax.set_xticks(x_ticks)
    ax.set_xticklabels(x_ticks, rotation=90, fontsize=30)
    ax.set_yticklabels(ax.get_yticks(), fontsize=30)

    # Ensure the plot is square-shaped
    ax.set_aspect('equal', adjustable='box')

    # Create a divider for existing axes instance
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.1)

    # Create the colorbar with the same height as the plot
    cbar = plt.colorbar(pcm, cax=cax)
    #cbar.set_label('Log Density', fontsize=30)
    cbar.ax.tick_params(labelsize=30)

    # Overlay the contour for density less than 0.01 rho_0
    contour_levels = [np.log10(threshold_density)]  # Level at threshold density
    contour = ax.contour(*rho_had.coordinates_meshgrid(), np.log10(r_had), levels=contour_levels, colors='red', linewidths=2)

    # Add label for the contour
    ax.clabel(contour, fmt={contour_levels[0]: '0.01 ρ₀'}, fontsize=20, colors='red')

# Save and display the plot
# plt.savefig("twint2_comparison_with_contours.pdf", format='pdf')
plt.show()
# Out:
# /tmp/ipykernel_3539/395213995.py:48: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=30)
# /tmp/ipykernel_3539/395213995.py:48: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=30)
# /tmp/ipykernel_3539/395213995.py:48: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=30)
# /tmp/ipykernel_3539/395213995.py:48: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=30)

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.axes_grid1 import make_axes_locatable

# Constants
rho_0 = 2.7e17  # Nuclear saturation density in kg/m^3
threshold_density = 0.01 * rho_0  # Threshold density

# Paths to different simulation directories
simulation_paths = [
    "/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Time Evolution/Grid2/Twin_t2_7",
    "/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Time Evolution/Grid2/Twin_t2_8",
    "/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Time Evolution/Grid2/Twin_t2_9",
    "/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Time Evolution/Grid2/Twin_t2_13"
]

# Plot setup
fig, axs = plt.subplots(1, 4, figsize=(60, 30))  # Create a 1x4 subplot

# Titles for subplots
titles = ["Twin A at t = 10 ms", "Twin B at t = 10 ms", "Twin C at t = 10 ms", "Twin D at t = 10 ms"]

# Iterate through each simulation path and plot
for i, sim_path in enumerate(simulation_paths):
    gf_had = SimDir(sim_path).gf
    rb_had = gf_had.xy.fields.rho
    small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[15, 15])
    rho_had = rb_had[54016].to_UniformGridData_from_grid(small_grid)
    r_had = rho_had.data_xyz

    ax = axs[i]  # Select the correct subplot axis
    rho_0 = 2.5e14 / (6.17627e17)  # Nuclear saturation density in kg/m^3
    threshold_density_1 = np.log10(0.01 * rho_0)
    threshold_density_2 = np.log10(0.1 * rho_0)
    threshold_density_3 = np.log10(rho_0)

    # Create a contour plot only at the threshold density
    ax.contour(*rho_had.coordinates_meshgrid(), np.log10(r_had), levels=[threshold_density_1, threshold_density_2, threshold_density_3], colors='blue')

    # Plot the pcolormesh
    pcm = ax.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')

    # Set axis labels with larger font size
    ax.set_xlabel('X', fontsize=30)
    ax.set_ylabel('Y', fontsize=30)

    # Set tick labels with larger font size
    x_ticks = np.arange(0, 15.1, 1)
    ax.set_xticks(x_ticks)
    ax.set_xticklabels(x_ticks, rotation=90, fontsize=30)
    ax.set_yticklabels(ax.get_yticks(), fontsize=30)

    # Ensure the plot is square-shaped
    ax.set_aspect('equal', adjustable='box')

    # Overlay the contour for density less than 0.01 rho_0
    contour_levels = [np.log10(threshold_density)]  # Level at threshold density
    contour = ax.contour(*rho_had.coordinates_meshgrid(), np.log10(r_had), levels=contour_levels, colors='red', linewidths=2)

    # Add label for the contour
    ax.clabel(contour, fmt={contour_levels[0]: '0.01 ρ₀'}, fontsize=20, colors='red')

    # Add the title to the subplot
    ax.set_title(titles[i], fontsize=35, loc='left')

# Create a single colorbar for all subplots with matching height
#cbar_ax = fig.add_axes([0.92, 0.15, 0.02, 0.7])  # [left, bottom, width, height]
fig.colorbar(pcm, cax=cbar_ax)

# Save and display the plot
plt.savefig("twint2_comparison_whole_54016_contours_with_colorbar.png")
plt.show()
# Out:
# /tmp/ipykernel_3539/2110923080.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=30)
# /tmp/ipykernel_3539/2110923080.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=30)
# /tmp/ipykernel_3539/2110923080.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=30)
# /tmp/ipykernel_3539/2110923080.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=30)

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.axes_grid1 import make_axes_locatable

# Constants
rho_0 = 2.7e17  # Nuclear saturation density in kg/m^3
threshold_density = 0.01 * rho_0  # Threshold density

# Paths to different simulation directories
simulation_paths = [
    "/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Time Evolution/Grid2/Twin_t2_7",
    "/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Time Evolution/Grid2/Twin_t2_8",
    "/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Time Evolution/Grid2/Twin_t2_9",
    "/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Time Evolution/Grid2/Twin_t2_13"
]

# Plot setup
fig, axs = plt.subplots(1, 4, figsize=(60, 30))  # Create a 1x4 subplot

# Titles for subplots
titles = ["Twin A at t = 0 ms", "Twin B at t = 0 ms", "Twin C at t = 0 ms", "Twin D at t = 0 ms"]

# Iterate through each simulation path and plot
for i, sim_path in enumerate(simulation_paths):
    gf_had = SimDir(sim_path).gf
    rb_had = gf_had.xy.fields.rho
    small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[15, 15])
    rho_had = rb_had[0].to_UniformGridData_from_grid(small_grid)
    r_had = rho_had.data_xyz

    ax = axs[i]  # Select the correct subplot axis
    rho_0 = 2.5e14 / (6.17627e17)  # Nuclear saturation density in kg/m^3
    threshold_density_1 = np.log10(0.01 * rho_0)
    threshold_density_2 = np.log10(0.1 * rho_0)
    threshold_density_3 = np.log10(rho_0)

    # Create a contour plot only at the threshold density
    #ax.contour(*rho_had.coordinates_meshgrid(), np.log10(r_had), levels=[threshold_density_1, threshold_density_2, threshold_density_3], colors='blue')

    # Plot the pcolormesh
    pcm = ax.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')

    # Set axis labels with larger font size
    ax.set_xlabel('X', fontsize=30)
    ax.set_ylabel('Y', fontsize=30)

    # Set tick labels with larger font size
    x_ticks = np.arange(0, 15.1, 1)
    ax.set_xticks(x_ticks)
    ax.set_xticklabels(x_ticks, rotation=90, fontsize=30)
    ax.set_yticklabels(ax.get_yticks(), fontsize=30)

    # Ensure the plot is square-shaped
    ax.set_aspect('equal', adjustable='box')

    # Overlay the contour for density less than 0.01 rho_0
    contour_levels = [np.log10(threshold_density)]  # Level at threshold density
    contour = ax.contour(*rho_had.coordinates_meshgrid(), np.log10(r_had), levels=contour_levels, colors='red', linewidths=2)

    # Add label for the contour
    ax.clabel(contour, fmt={contour_levels[0]: '0.01 ρ₀'}, fontsize=20, colors='red')

    # Add the title to the subplot
    ax.set_title(titles[i], fontsize=35, loc='left')

# Create a single colorbar for all subplots with matching height
#cbar_ax = fig.add_axes([0.92, 0.15, 0.02, 0.7])  # [left, bottom, width, height]
fig.colorbar(pcm, cax=cbar_ax)

# Save and display the plot
plt.savefig("twint2_comparison_whole_0_contours_with_colorbar.png")
plt.show()
# Out:
# /tmp/ipykernel_3539/633772959.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=30)
# /tmp/ipykernel_3539/633772959.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=30)
# /tmp/ipykernel_3539/633772959.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=30)
# /tmp/ipykernel_3539/633772959.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=30)

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.axes_grid1 import make_axes_locatable

# Constants
rho_0 = 2.7e17  # Nuclear saturation density in kg/m^3
threshold_density = 0.01 * rho_0  # Threshold density

# Paths to different simulation directories
simulation_paths = [
    "/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Time Evolution/Grid2/Twin_r5_11",
    "/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Time Evolution/Grid2/Twin_r5_12",
    "/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Time Evolution/Grid2/Twin_r5_13"
]

# Plot setup
fig, axs = plt.subplots(1, 3, figsize=(60, 30))  # Create a 1x3 subplot

# Titles for subplots
titles = ["Twin A at t = 0 ms", "Twin B at t = 0 ms", "Twin C at t = 0 ms"]

# Iterate through each simulation path and plot
for i, sim_path in enumerate(simulation_paths):
    gf_had = SimDir(sim_path).gf  # Assuming SimDir is defined somewhere
    rb_had = gf_had.xy.fields.rho
    small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[15, 15])  # Assuming UniformGrid is defined somewhere
    rho_had = rb_had[0].to_UniformGridData_from_grid(small_grid)
    r_had = rho_had.data_xyz

    ax = axs[i]  # Select the correct subplot axis
    threshold_density_1 = np.log10(0.01 * rho_0)
    threshold_density_2 = np.log10(0.1 * rho_0)
    threshold_density_3 = np.log10(rho_0)

    # Create a contour plot only at the threshold density
    ax.contour(*rho_had.coordinates_meshgrid(), np.log10(r_had), levels=[threshold_density_1, threshold_density_2, threshold_density_3], colors='blue')

    # Plot the pcolormesh
    pcm = ax.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')

    # Set axis labels with larger font size
    ax.set_xlabel('X', fontsize=30)
    ax.set_ylabel('Y', fontsize=30)

    # Set tick labels with larger font size
    x_ticks = np.arange(0, 15.1, 1)
    ax.set_xticks(x_ticks)
    ax.set_xticklabels(x_ticks, rotation=90, fontsize=30)
    ax.set_yticklabels(ax.get_yticks(), fontsize=30)

    # Ensure the plot is square-shaped
    ax.set_aspect('equal', adjustable='box')

    # Overlay the contour for density less than 0.01 rho_0
    contour_levels = [np.log10(threshold_density)]  # Level at threshold density
    contour = ax.contour(*rho_had.coordinates_meshgrid(), np.log10(r_had), levels=contour_levels, colors='red', linewidths=2)

    # Add label for the contour
    ax.clabel(contour, fmt={contour_levels[0]: '0.01 ρ₀'}, fontsize=20, colors='red')

    # Add the title to the subplot
    ax.set_title(titles[i], fontsize=35, loc='left')

# Create a single colorbar for all subplots with matching height
#cbar_ax = fig.add_axes([0.92, 0.15, 0.02, 0.7])  # [left, bottom, width, height]
#fig.colorbar(pcm, cax=cbar_ax)

# Save and display the plot
plt.savefig("twinr5_comparison_whole_0_contours_with_colorbar.png")
plt.show()
# Out:
# /tmp/ipykernel_3539/1344712192.py:49: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=30)
# /tmp/ipykernel_3539/1344712192.py:49: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=30)
# /tmp/ipykernel_3539/1344712192.py:49: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=30)

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.axes_grid1 import make_axes_locatable

# Constants
rho_0 = 2.7e17  # Nuclear saturation density in kg/m^3
threshold_density = 0.01 * rho_0  # Threshold density

# Paths to different simulation directories
simulation_paths = [
    "/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Time Evolution/Grid2/Twin_r5_11",
    "/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Time Evolution/Grid2/Twin_r5_12",
    "/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Time Evolution/Grid2/Twin_r5_13"
]

# Plot setup
fig, axs = plt.subplots(1, 3, figsize=(60, 30))  # Create a 1x3 subplot

# Titles for subplots
titles = ["Twin A at t = 0 ms", "Twin B at t = 0 ms", "Twin C at t = 0 ms"]

# Iterate through each simulation path and plot
for i, sim_path in enumerate(simulation_paths):
    gf_had = SimDir(sim_path).gf  # Assuming SimDir is defined somewhere
    rb_had = gf_had.xy.fields.rho
    small_grid = UniformGrid([500, 500], x0=[0, 0], x1=[15, 15])  # Assuming UniformGrid is defined somewhere
    rho_had = rb_had[54016].to_UniformGridData_from_grid(small_grid)
    r_had = rho_had.data_xyz

    ax = axs[i]  # Select the correct subplot axis
    threshold_density_1 = np.log10(0.01 * rho_0)
    threshold_density_2 = np.log10(0.1 * rho_0)
    threshold_density_3 = np.log10(rho_0)

    # Create a contour plot only at the threshold density
    ax.contour(*rho_had.coordinates_meshgrid(), np.log10(r_had), levels=[threshold_density_1, threshold_density_2, threshold_density_3], colors='blue')

    # Plot the pcolormesh
    pcm = ax.pcolormesh(*rho_had.coordinates_meshgrid(), np.log10(r_had), shading='auto')

    # Set axis labels with larger font size
    ax.set_xlabel('X', fontsize=30)
    ax.set_ylabel('Y', fontsize=30)

    # Set tick labels with larger font size
    x_ticks = np.arange(0, 15.1, 1)
    ax.set_xticks(x_ticks)
    ax.set_xticklabels(x_ticks, rotation=90, fontsize=30)
    ax.set_yticklabels(ax.get_yticks(), fontsize=30)

    # Ensure the plot is square-shaped
    ax.set_aspect('equal', adjustable='box')

    # Overlay the contour for density less than 0.01 rho_0
    contour_levels = [np.log10(threshold_density)]  # Level at threshold density
    contour = ax.contour(*rho_had.coordinates_meshgrid(), np.log10(r_had), levels=contour_levels, colors='red', linewidths=2)

    # Add label for the contour
    ax.clabel(contour, fmt={contour_levels[0]: '0.01 ρ₀'}, fontsize=20, colors='red')

    # Add the title to the subplot
    ax.set_title(titles[i], fontsize=35, loc='left')

# Create a single colorbar for all subplots with matching height
cbar_ax = fig.add_axes([0.92, 0.15, 0.02, 0.7])  # [left, bottom, width, height]
fig.colorbar(pcm, cax=cbar_ax)

# Save and display the plot
plt.savefig("twinr5_comparison_whole_54016_contours_with_colorbar.png")
plt.show()
# Out:
# /tmp/ipykernel_3539/1108474880.py:49: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=30)
# /tmp/ipykernel_3539/1108474880.py:49: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=30)
# /tmp/ipykernel_3539/1108474880.py:49: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=30)
