# %%
import matplotlib.pyplot as plt
from kuibit.simdir import SimDir
import kuibit.visualize_matplotlib as viz
from kuibit.simdir import SimDir
from kuibit.grid_data import UniformGrid
from matplotlib import rcParams
rcParams['text.usetex'] = True
rcParams["font.family"] = "Times New Roman"

# %%
iteration_number = 0
sim = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Time Evolution/Grid2/Twin_t2_7")
rho_xy = sim.gridfunctions.xy["rho"][iteration_number]

rho_xy_unif = rho_xy.to_UniformGridData(shape=[100, 100], 
                                        x0=[0,0],
                                        x1=[8, 8],
                                        resample=True)

# Undo reflection symmetry on the x axis
rho_xy_unif.reflection_symmetry_undo(dimension=0)
# Undo reflection symmetry on the y axis
rho_xy_unif.reflection_symmetry_undo(dimension=1)

viz.plot_color(rho_xy_unif,
               logscale=True,
               colorbar=True,
               label="Rest Mass Desnity",
               xlabel="x",
               ylabel="y",
               cmap="inferno",
              )

plt.savefig('Full_t2_7.png')
plt.show()

# %%
iteration_number = 0
sim = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Time Evolution/Grid2/Twin_t2_13")
rho_xy = sim.gridfunctions.xy["rho"][iteration_number]

rho_xy_unif = rho_xy.to_UniformGridData(shape=[100, 100], 
                                        x0=[0,0],
                                        x1=[15, 15],
                                        resample=True)

# Undo reflection symmetry on the x axis
rho_xy_unif.reflection_symmetry_undo(dimension=0)
# Undo reflection symmetry on the y axis
rho_xy_unif.reflection_symmetry_undo(dimension=1)

viz.plot_color(rho_xy_unif,
               logscale=True,
               colorbar=True,
               label="Rest Mass Desnity",
               xlabel="x",
               ylabel="y",
               cmap="inferno",
              )

plt.savefig('Full_t2_13.png')
plt.show()

# %%
iteration_number = 0
sim = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Time Evolution/Grid2/Twin_r5_13")
rho_xy = sim.gridfunctions.xy["rho"][iteration_number]

rho_xy_unif = rho_xy.to_UniformGridData(shape=[100, 100], 
                                        x0=[0,0],
                                        x1=[15, 15],
                                        resample=True)

# Undo reflection symmetry on the x axis
rho_xy_unif.reflection_symmetry_undo(dimension=0)
# Undo reflection symmetry on the y axis
rho_xy_unif.reflection_symmetry_undo(dimension=1)

viz.plot_color(rho_xy_unif,
               logscale=True,
               colorbar=True,
               label="Rest Mass Desnity",
               xlabel="x",
               ylabel="y",
               cmap="inferno",
              )

plt.savefig('Full_r5_13.png')
plt.show()

# %%
iteration_number = 0
sim = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Time Evolution/Grid2/Twin_r5_11")
rho_xy = sim.gridfunctions.xy["rho"][iteration_number]

rho_xy_unif = rho_xy.to_UniformGridData(shape=[100, 100], 
                                        x0=[0,0],
                                        x1=[10, 10],
                                        resample=True)

# Undo reflection symmetry on the x axis
rho_xy_unif.reflection_symmetry_undo(dimension=0)
# Undo reflection symmetry on the y axis
rho_xy_unif.reflection_symmetry_undo(dimension=1)

viz.plot_color(rho_xy_unif,
               logscale=True,
               colorbar=True,
               label="Rest Mass Desnity",
               xlabel="x",
               ylabel="y",
               cmap="inferno",
              )

plt.savefig('Full_r5_11.png')
plt.show()

# %%
iteration_number = 0
sim = SimDir("/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Time Evolution/Grid2/Twin_t2_7")
rho_xy = sim.gridfunctions.xy["rho"][iteration_number]

# Convert to uniform grid data
rho_xy_unif = rho_xy.to_UniformGridData(shape=[100, 100], 
                                        x0=[0,0],
                                        x1=[8, 8],
                                        resample=True)

# Undo reflection symmetry on the x axis
rho_xy_unif.reflection_symmetry_undo(dimension=0)
# Undo reflection symmetry on the y axis
rho_xy_unif.reflection_symmetry_undo(dimension=1)

# Plot the log density
viz.plot_color(rho_xy_unif,
               logscale=True,   # Logarithmic scale for the color mapping
               colorbar=True,
               label="Rest Mass Density",
               xlabel="x",
               ylabel="y",
               cmap="inferno",   # Color map choice
              )

# Save the plot
plt.savefig('Full_t2_7.png')
plt.show()
