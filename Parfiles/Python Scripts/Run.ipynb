# %%
from datetime import datetime

# %%
start_time = datetime.now()

# !./simfactory/bin/sim create-submit Twin_t2_7 --parfile=par/tov_t2_7_time.par --procs=8 --num-threads=2
# !./simfactory/bin/sim show-output --follow Twin_t2_7

end_time = datetime.now()
print('Duration: {}'.format(end_time-start_time))
# Out:
# Parameter file: /home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/Cactus/par/tov_t2_7_time.par
# Skeleton Created
# Job directory: "/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Twin_t2_7"
# Executable: "/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/Cactus/exe/cactus_sim"
# Option list: "/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Twin_t2_7/SIMFACTORY/cfg/OptionList"
# Submit script: "/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Twin_t2_7/SIMFACTORY/run/SubmitScript"
# Run script: "/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Twin_t2_7/SIMFACTORY/run/RunScript"
# Parameter file: "/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Twin_t2_7/SIMFACTORY/par/tov_t2_7_time.par"
# Assigned restart id: 0
# ...

# %%
start_time = datetime.now()

# !./simfactory/bin/sim create-submit Twin_t2_8 --parfile=par/tov_t2_8_time.par --procs=8 --num-threads=2
# !./simfactory/bin/sim show-output --follow Twin_t2_8

end_time = datetime.now()
print('Duration: {}'.format(end_time-start_time))
# Out:
# Parameter file: /home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/Cactus/par/tov_t2_8_time.par
# Skeleton Created
# Job directory: "/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Twin_t2_8"
# Executable: "/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/Cactus/exe/cactus_sim"
# Option list: "/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Twin_t2_8/SIMFACTORY/cfg/OptionList"
# Submit script: "/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Twin_t2_8/SIMFACTORY/run/SubmitScript"
# Run script: "/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Twin_t2_8/SIMFACTORY/run/RunScript"
# Parameter file: "/home/ron_mukherjee/Documents/WhiskyTHC4/WhiskyTHC/FreeTHC/simulations/Twin_t2_8/SIMFACTORY/par/tov_t2_8_time.par"
# Assigned restart id: 0
# ...

# %%
start_time = datetime.now()

# !./simfactory/bin/sim create-submit Twin_t2_9 --parfile=par/tov_t2_9_time.par --procs=8 --num-threads=2
# !./simfactory/bin/sim show-output --follow Twin_t2_9

end_time = datetime.now()
print('Duration: {}'.format(end_time-start_time))

# %%
start_time = datetime.now()

# !./simfactory/bin/sim create-submit Twin_t2_13 --parfile=par/tov_t2_13_time.par --procs=8 --num-threads=2
# !./simfactory/bin/sim show-output --follow Twin_t2_13

end_time = datetime.now()
print('Duration: {}'.format(end_time-start_time))

# %%
start_time = datetime.now()

# !./simfactory/bin/sim create-submit Twin_r5_11 --parfile=par/tov_r5_11_time.par --procs=8 --num-threads=2
# !./simfactory/bin/sim show-output --follow Twin_r5_11

end_time = datetime.now()
print('Duration: {}'.format(end_time-start_time))

# %%
start_time = datetime.now()

# !./simfactory/bin/sim create-submit Twin_r5_12 --parfile=par/tov_r5_12_time.par --procs=8 --num-threads=2
# !./simfactory/bin/sim show-output --follow Twin_r5_12

end_time = datetime.now()
print('Duration: {}'.format(end_time-start_time))

# %%
start_time = datetime.now()

# !./simfactory/bin/sim create-submit Twin_r5_13 --parfile=par/tov_r5_13_time.par --procs=8 --num-threads=2
# !./simfactory/bin/sim show-output --follow Twin_r5_13

end_time = datetime.now()
print('Duration: {}'.format(end_time-start_time))
